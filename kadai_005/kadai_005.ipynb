# %%
str((int(10+int(20)) * int(5))/2)+"㎠"
# Out:
# '75.0㎠'

# %%
user_name = "侍太郎"
print(user_name)

user_name = "侍花子"
print(user_name)
# Out:
# 侍太郎
# 侍花子

# %%
last_name = "侍"
first_name = "太郎"
print(last_name + first_name)
# Out:
# 侍太郎

# %%
last_name = "侍"
first_name = "太郎"
sister_name = "花子"

print(f"私の名前は{last_name}{first_name}です。妹の名前は{sister_name}です。")
# Out:
# 私の名前は侍太郎です。妹の名前は花子です。

# %%
#台形の面積を計算
print(((10+20)*5)/2)

#台形の計算結果を変数とする
daikei = "75"

#台形の面積と㎠を結合
print(str(daikei) + "㎠")
# Out:
# 75.0
# 75㎠

# %%
#課題の再提出
daikei = ((10+20)*5)/2

print(str(daikei) + "㎠")
# Out:
# 75.0㎠
