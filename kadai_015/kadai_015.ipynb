# %%
class Human:
    def __init__ (self, name, age):
      #属性を定義する
      self.name = name
      self.age = age

    #メソッドを定義する
    def printinfo(self):
        print(self.name)
        print(self.age)

#インスタンス化
human = Human("太郎", 22)

#値を出力
human.printinfo()
# Out:
# 太郎
# 22
