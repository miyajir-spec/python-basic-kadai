# %%
import random

var = random.randint(0,999)

# 3と5の両方の倍数の場合はFizzBuzz
if var % 3 == 0:
    print("FizzBuzz")
elif var % 5 == 0:
    print("FizzBuzz")
elif var % 3 == 0:
    print("Fizz")
elif var % 5 == 0:
    print("Buzz")
else :
    print(var)
# Out:
# 964
